# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904836-hub/python1/blob/main/t%E1%BB%95ng_t%E1%BB%AB_0_%C4%91%E1%BA%BFn_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Nhập số nguyên dương n:"))
x = 0
for i in range(n + 1):
  x += i
  print(f"Tổng các số từ 0 đến {n} là {x}")
# Out:
# Nhập số nguyên dương n:6
# Tổng các số từ 0 đến 6 là 0
# Tổng các số từ 0 đến 6 là 1
# Tổng các số từ 0 đến 6 là 3
# Tổng các số từ 0 đến 6 là 6
# Tổng các số từ 0 đến 6 là 10
# Tổng các số từ 0 đến 6 là 15
# Tổng các số từ 0 đến 6 là 21
