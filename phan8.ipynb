# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904836-hub/python1/blob/main/phan8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
arr = numpy.array([1, 2, 3])
print(arr)
import numpy as np
arr = np.array([1, 2, 3])
print(arr)
r = 0.43
import math
C = 2 * math.pi * r
S = math.pi * r **2
print("Chu vi: " + str(C))
print("Diện tích: " + str(S))
r = 192500
from  math import radians
dist = radians(12) * r
print(dist)
# Out:
# [1 2 3]
# [1 2 3]
# Chu vi: 2.701769682087222
# Diện tích: 0.5808804816487527
# 40317.10572106901
