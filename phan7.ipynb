# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904836-hub/python1/blob/main/phan7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
room = "poolhouse"
room_up = room.upper()
print(room, room_up)
print(len(room))
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
print(areas.index(20))
print(areas.count(14.5))
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
areas.append(24.5)
areas.append(15.45)
print(areas)
areas.reverse()
print(areas)
# Out:
# poolhouse POOLHOUSE
# 9
# 2
# 0
# [11.25, 18.0, 20.0, 10.75, 9.5, 24.5, 15.45]
# [15.45, 24.5, 9.5, 10.75, 20.0, 18.0, 11.25]
